# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as s
from numpy import cos, sqrt, radians

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

from sklearn import metrics

from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR

# %%
dataset = pd.read_csv("merged_data_mass.csv")
dataset.head()
# Out:
#              Compounds A sites  A site charge  A site mass  \
# 0  (HIm)2[KFeIII(CN)6]     HIm              1    69.085331
# 1  (HIm)2[KCoIII(CN)6]     HIm              1    69.085331
# 2   (MA)2[KFeIII(CN)6]      MA              1    32.065089
# 3  (MA)2[NaCoIII(CN)6]      MA              1    32.065089
# 4   (MA)2[KCoIII(CN)6]      MA              1    32.065089
#
#             Principle components of inertia       B sites  Elpasolite?  \
# 0  [ 59.08125339  63.65097475 122.73222814]   ['K', 'Fe']         True
# 1  [ 59.08125339  63.65097475 122.73222814]   ['K', 'Co']         True
# 2     [ 6.04053294 24.31989658 24.32009471]   ['K', 'Fe']         True
# 3     [ 6.04053294 24.31989658 24.32009471]  ['Na', 'Co']         True
# 4     [ 6.04053294 24.31989658 24.32009471]   ['K', 'Co']         True
#
#   B site charge B1 site  B1 charge  ...  \
# 0      [+1, +3]       K          1  ...
# 1      [+1, +3]       K          1  ...
# 2      [+1, +3]       K          1  ...
# ...

# %%
dataset.columns
# Out:
# Index(['Compounds', 'A sites', 'A site charge', 'A site mass',
#        'Principle components of inertia', 'B sites', 'Elpasolite?',
#        'B site charge', 'B1 site', 'B1 charge', 'B1 ionic radii', 'B1 mass',
#        'B2 site', 'B2 charge', 'B2 ionic radii', 'B2 mass', 'X sites',
#        'X site charge', 'X site length', 'X site mass', 'T c/K',
#        'No. of phase transitions', 'Space groupa', 'Space group ref', 'a',
#        'da', 'b', 'db', 'c', 'dc', 'alpha', 'dalpha', 'beta', 'dbeta', 'gamma',
#        'dgamma', 'Ref.', 'DOI', 'alpha1', 'alpha2', 'alpha3', 'alphar',
#        'alphatheta', 'Lmin', 'Lmed', 'Lmax', 'b_y'],
#       dtype='object')

# %%
X, y = np.array(dataset[['X site mass']]), np.array(dataset[['X site length']])
plt.scatter(X, y, color = 'red', s = 2)
plt.title('X-Site Mass Against X-Length')
plt.xlabel('X-Mass (Atomic Units)')
plt.ylabel('X-Length (Angstroms)')
plt.show()
X, y = np.array(dataset[['A site mass']]), np.array(dataset[['X site length']])
plt.scatter(X, y, color = 'b', s = 2)
plt.title('A-Site Mass Against X-Length')
plt.xlabel('A-Mass (Atomic Units)')
plt.ylabel('X-Length (Angstroms)')
plt.show()
